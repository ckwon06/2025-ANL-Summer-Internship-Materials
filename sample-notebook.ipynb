# %% [markdown]
# # Experiments for Identifying Critical Grid Components with LLMs
#
# We assess whether ChatGPT can be utilized to find a critical component of the electric grid. To that end, we consider `case9`, `case30`, and `case118`.
#
# ## Case 9
#
# We solve power flow with case9 instance as is in `pandapower`. Let's install the package first.

# %%
# %conda update -c conda-forge pandapower --yes
# %conda update -c conda-forge numpy --yes
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/kibaekkim/miniconda3
#
#   added / updated specs:
#     - pandapower
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.5             |     pyhd8ed1ab_0          50 KB  conda-forge
#     boltons-25.0.0             |     pyhd8ed1ab_0         295 KB  conda-forge
#     brotli-python-1.1.0        |  py312hd8f9ff3_3         331 KB  conda-forge
#     c-ares-1.34.5              |       h5505292_0         175 KB  conda-forge
#     charset-normalizer-3.4.2   |     pyhd8ed1ab_0          49 KB  conda-forge
#     conda-package-handling-2.4.0|     pyh7900ff3_2         252 KB  conda-forge
#     conda-package-streaming-0.11.0|     pyhd8ed1ab_1          20 KB  conda-forge
#     cpp-expected-1.1.0         |       h177bc72_1          24 KB  conda-forge
# ...

# %%
# %pip uninstall pandapower --yes
# %pip uninstall numpy --yes

# %conda install -c conda-forge pandapower --yes
# %conda install -c conda-forge numpy --yes
# Out:
# Found existing installation: pandapower 3.1.2
# Uninstalling pandapower-3.1.2:
#   Successfully uninstalled pandapower-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: numpy 2.3.0
# Uninstalling numpy-2.3.0:
#   Successfully uninstalled numpy-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# Retrieving notices: done
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/kibaekkim/miniconda3
#
#   added / updated specs:
#     - pandapower=2.8.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.6.15  |       hbd8a1cb_0         148 KB  conda-forge
#     certifi-2025.6.15          |     pyhd8ed1ab_0         152 KB  conda-forge
# ...

# %%
import pandapower as pp
import pandapower.networks as pn
import pandapower.shortcircuit as sc

net_case9 = pn.case9()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandapower as pp
#       2 import pandapower.networks as pn
#       3 import pandapower.shortcircuit as sc
#
# File ~/miniconda3/lib/python3.12/site-packages/pandapower/__init__.py:9
#       7 from pandapower.create import *
#       8 from pandapower.convert_format import *
# ----> 9 from pandapower.file_io import *
#      10 from pandapower.sql_io import to_postgresql, from_postgresql, delete_postgresql_net, to_sqlite, from_sqlite
#      11 from pandapower.powerflow import *
#
# File ~/miniconda3/lib/python3.12/site-packages/pandapower/file_io.py:32
#      30 from pandapower.auxiliary import soft_dependency_error
#      31 from pandapower.auxiliary import pandapowerNet
# ---> 32 from pandapower.std_types import basic_std_types
#      33 from pandapower.create import create_empty_network
# ...
